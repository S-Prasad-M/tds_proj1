# %%
import requests
import pandas as pd
import time
import logging
from typing import List, Dict, Any

# %%
class GitHubScraper:
    def __init__(self, token: str):
        """
        Initialize the GitHub scraper with your API token.
        
        Args:
            token (str): GitHub Personal Access Token
        """
        self.headers = {
            'Authorization': f'token {token}',
            'Accept': 'application/vnd.github.v3+json'
        }
        self.base_url = 'https://api.github.com'
        
        # Setup logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        self.logger = logging.getLogger(__name__)

    def _make_request(self, url: str, params: dict = None) -> Dict:
        """
        Make a request to the GitHub API with rate limit handling.
        """
        while True:
            response = requests.get(url, headers=self.headers, params=params)
            
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 403:
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                sleep_time = max(reset_time - time.time(), 0) + 1
                self.logger.warning(f"Rate limit hit. Sleeping for {sleep_time} seconds")
                time.sleep(sleep_time)
            else:
                self.logger.error(f"Error {response.status_code}: {response.text}")
                response.raise_for_status()

    def clean_company_name(self, company: str) -> str:
        """
        Clean up company names according to specifications.
        """
        if not company:
            return ""
        
        # Strip whitespace and @ symbol
        cleaned = company.strip().lstrip('@')
        
        # Convert to uppercase
        return cleaned.upper()

    def search_users(self, location: str, min_followers: int) -> List[Dict]:
        """
        Search for GitHub users in a specific location with minimum followers.
        """
        users = []
        page = 1
        
        while True:
            self.logger.info(f"Fetching users page {page}")
            
            query = f"location:{location} followers:>={min_followers}"
            params = {
                'q': query,
                'per_page': 100,
                'page': page
            }
            
            url = f"{self.base_url}/search/users"
            response = self._make_request(url, params)
            
            if not response['items']:
                break
                
            for user in response['items']:
                user_data = self._make_request(user['url'])
                
                # Extract only the required fields with exact matching names
                cleaned_data = {
                    'login': user_data['login'],
                    'name': user_data['name'] if user_data['name'] else "",
                    'company': self.clean_company_name(user_data.get('company')),
                    'location': user_data['location'] if user_data['location'] else "",
                    'email': user_data['email'] if user_data['email'] else "",
                    'hireable': user_data['hireable'] if user_data['hireable'] is not None else False,
                    'bio': user_data['bio'] if user_data['bio'] else "",
                    'public_repos': user_data['public_repos'],
                    'followers': user_data['followers'],
                    'following': user_data['following'],
                    'created_at': user_data['created_at']
                }
                
                users.append(cleaned_data)
                
            page += 1
            
        return users

    def get_user_repositories(self, username: str, max_repos: int = 500) -> List[Dict]:
        """
        Get repositories for a specific user.
        """
        repos = []
        page = 1
        
        while len(repos) < max_repos:
            self.logger.info(f"Fetching repositories for {username}, page {page}")
            
            params = {
                'sort': 'pushed',
                'direction': 'desc',
                'per_page': 100,
                'page': page
            }
            
            url = f"{self.base_url}/users/{username}/repos"
            response = self._make_request(url, params)
            
            if not response:
                break
                
            for repo in response:
                # Extract only the required fields with exact matching names
                repo_data = {
                    'login': username,  # Adding owner's login as required
                    'full_name': repo['full_name'],
                    'created_at': repo['created_at'],
                    'stargazers_count': repo['stargazers_count'],
                    'watchers_count': repo['watchers_count'],
                    'language': repo['language'] if repo['language'] else "",
                    'has_projects': repo['has_projects'],
                    'has_wiki': repo['has_wiki'],
                    'license_name': repo['license']['key'] if repo.get('license') else ""
                }
                
                repos.append(repo_data)
                
            if len(response) < 100:
                break
                
            page += 1
            
        return repos[:max_repos]

# %%
token = "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"

# %%
scraper = GitHubScraper(token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 scraper = GitHubScraper(token)
#
# NameError: name 'GitHubScraper' is not defined

# %%
users = scraper.search_users(location='Delhi', min_followers=100)
# Save users to CSV
users_df = pd.DataFrame(users)
users_df.to_csv('users.csv', index=False)
# Get repositories for each user
all_repos = []
for user in users:
    repos = scraper.get_user_repositories(user['login'])
    all_repos.extend(repos)
# Save repositories to CSV
repos_df = pd.DataFrame(all_repos)
repos_df.to_csv('repositories.csv', index=False)
print(f"Scraped {len(users)} users and {len(all_repos)} repositories")
# Out:
# 2024-10-31 00:26:00,445 - INFO - Fetching users page 1
# 2024-10-31 00:26:59,055 - INFO - Fetching users page 2
# 2024-10-31 00:27:54,048 - INFO - Fetching users page 3
# 2024-10-31 00:28:49,290 - INFO - Fetching users page 4
# 2024-10-31 00:30:19,504 - INFO - Fetching users page 5
# 2024-10-31 00:30:33,390 - INFO - Fetching users page 6
# 2024-10-31 00:30:33,978 - INFO - Fetching repositories for amitshekhariitbhu, page 1
# 2024-10-31 00:30:35,026 - INFO - Fetching repositories for shradha-khapra, page 1
# 2024-10-31 00:30:35,934 - INFO - Fetching repositories for loveBabbar, page 1
# 2024-10-31 00:30:36,855 - INFO - Fetching repositories for Nakshatra05, page 1
# 2024-10-31 00:30:37,888 - INFO - Fetching repositories for Anuj-Kumar-Sharma, page 1
# 2024-10-31 00:30:38,855 - INFO - Fetching repositories for Ignitetechnologies, page 1
# 2024-10-31 00:30:39,802 - INFO - Fetching repositories for developerrahulofficial, page 1
# 2024-10-31 00:30:41,164 - INFO - Fetching repositories for farhan7reza7, page 1
# 2024-10-31 00:30:42,452 - INFO - Fetching repositories for farhan7reza7, page 2
# 2024-10-31 00:30:42,926 - INFO - Fetching repositories for janishar, page 1
# 2024-10-31 00:30:43,983 - INFO - Fetching repositories for shivaylamba, page 1
# 2024-10-31 00:30:46,264 - INFO - Fetching repositories for shivaylamba, page 2
# 2024-10-31 00:30:47,586 - INFO - Fetching repositories for shivaylamba, page 3
# 2024-10-31 00:30:49,499 - INFO - Fetching repositories for shivaylamba, page 4
# 2024-10-31 00:30:50,296 - INFO - Fetching repositories for naman14, page 1
# 2024-10-31 00:30:51,585 - INFO - Fetching repositories for aviaryan, page 1
# 2024-10-31 00:30:53,088 - INFO - Fetching repositories for aviaryan, page 2
# 2024-10-31 00:30:54,348 - INFO - Fetching repositories for the-dagger, page 1
# 2024-10-31 00:30:55,615 - INFO - Fetching repositories for Priyansh19077, page 1
# 2024-10-31 00:30:56,355 - INFO - Fetching repositories for mehulmpt, page 1
# 2024-10-31 00:30:57,938 - INFO - Fetching repositories for mehulmpt, page 2
# 2024-10-31 00:30:59,027 - INFO - Fetching repositories for kunaltyagi9, page 1
# 2024-10-31 00:30:59,918 - INFO - Fetching repositories for ShreyaPrasad1209, page 1
# 2024-10-31 00:31:01,407 - INFO - Fetching repositories for ShreyaPrasad1209, page 2
# 2024-10-31 00:31:02,554 - INFO - Fetching repositories for nathvarun, page 1
# 2024-10-31 00:31:03,855 - INFO - Fetching repositories for Swati4star, page 1
# 2024-10-31 00:31:04,955 - INFO - Fetching repositories for saumya1singh, page 1
# 2024-10-31 00:31:06,438 - INFO - Fetching repositories for saumya1singh, page 2
# 2024-10-31 00:31:08,262 - INFO - Fetching repositories for saumya1singh, page 3
# 2024-10-31 00:31:09,339 - INFO - Fetching repositories for SnippetCoders, page 1
# 2024-10-31 00:31:10,337 - INFO - Fetching repositories for nikhilkumarsingh, page 1
# 2024-10-31 00:31:11,876 - INFO - Fetching repositories for nikhilkumarsingh, page 2
# 2024-10-31 00:31:12,425 - INFO - Fetching repositories for AakashKumarNain, page 1
# 2024-10-31 00:31:13,438 - INFO - Fetching repositories for PrathamKumar14, page 1
# 2024-10-31 00:31:15,267 - INFO - Fetching repositories for coderdost, page 1
# 2024-10-31 00:31:16,051 - INFO - Fetching repositories for manrajgrover, page 1
# 2024-10-31 00:31:17,368 - INFO - Fetching repositories for manrajgrover, page 2
# 2024-10-31 00:31:18,948 - INFO - Fetching repositories for manrajgrover, page 3
# 2024-10-31 00:31:19,748 - INFO - Fetching repositories for rishikksh20, page 1
# 2024-10-31 00:31:21,180 - INFO - Fetching repositories for aayusharora, page 1
# 2024-10-31 00:31:22,447 - INFO - Fetching repositories for aayusharora, page 2
# 2024-10-31 00:31:23,344 - INFO - Fetching repositories for AkshayAnand2002, page 1
# 2024-10-31 00:31:25,044 - INFO - Fetching repositories for AkshayAnand2002, page 2
# 2024-10-31 00:31:26,363 - INFO - Fetching repositories for KeenWarrior, page 1
# 2024-10-31 00:31:27,635 - INFO - Fetching repositories for KeenWarrior, page 2
# 2024-10-31 00:31:28,648 - INFO - Fetching repositories for ayooshkathuria, page 1
# 2024-10-31 00:31:29,608 - INFO - Fetching repositories for abhishekaryangiri, page 1
# 2024-10-31 00:31:30,736 - INFO - Fetching repositories for unnati914, page 1
# 2024-10-31 00:31:32,093 - INFO - Fetching repositories for unnati914, page 2
# 2024-10-31 00:31:33,418 - INFO - Fetching repositories for rishz, page 1
# 2024-10-31 00:31:35,275 - INFO - Fetching repositories for Vishal-raj-1, page 1
# 2024-10-31 00:31:36,466 - INFO - Fetching repositories for monukumar98, page 1
# 2024-10-31 00:31:37,482 - INFO - Fetching repositories for thismlguy, page 1
# 2024-10-31 00:31:38,554 - INFO - Fetching repositories for msfjarvis, page 1
# 2024-10-31 00:31:40,004 - INFO - Fetching repositories for Swarnika07, page 1
# 2024-10-31 00:31:40,553 - INFO - Fetching repositories for AmanPathak-DevOps, page 1
# 2024-10-31 00:31:41,371 - INFO - Fetching repositories for KhushbooGoel01, page 1
# 2024-10-31 00:31:42,265 - INFO - Fetching repositories for sharmaroshan, page 1
# 2024-10-31 00:31:43,909 - INFO - Fetching repositories for sharmaroshan, page 2
# 2024-10-31 00:31:44,705 - INFO - Fetching repositories for bpbpublications, page 1
# 2024-10-31 00:31:46,721 - INFO - Fetching repositories for bpbpublications, page 2
# 2024-10-31 00:31:48,168 - INFO - Fetching repositories for bpbpublications, page 3
# 2024-10-31 00:31:50,778 - INFO - Fetching repositories for bpbpublications, page 4
# 2024-10-31 00:31:53,585 - INFO - Fetching repositories for bpbpublications, page 5
# 2024-10-31 00:31:55,015 - INFO - Fetching repositories for ragdroid, page 1
# 2024-10-31 00:31:56,278 - INFO - Fetching repositories for shashankrustagi, page 1
# 2024-10-31 00:31:57,361 - INFO - Fetching repositories for Ayush7614, page 1
# 2024-10-31 00:31:59,746 - INFO - Fetching repositories for Ayush7614, page 2
# 2024-10-31 00:32:01,904 - INFO - Fetching repositories for Ayush7614, page 3
# 2024-10-31 00:32:04,764 - INFO - Fetching repositories for Ayush7614, page 4
# 2024-10-31 00:32:06,274 - INFO - Fetching repositories for Ayush7614, page 5
# 2024-10-31 00:32:07,636 - INFO - Fetching repositories for AzeemIdrisi, page 1
# 2024-10-31 00:32:08,874 - INFO - Fetching repositories for dufferzafar, page 1
# 2024-10-31 00:32:10,479 - INFO - Fetching repositories for dufferzafar, page 2
# 2024-10-31 00:32:11,719 - INFO - Fetching repositories for someshkar, page 1
# 2024-10-31 00:32:12,605 - INFO - Fetching repositories for ShivamJoker, page 1
# 2024-10-31 00:32:14,105 - INFO - Fetching repositories for ShivamJoker, page 2
# 2024-10-31 00:32:15,365 - INFO - Fetching repositories for eKuG, page 1
# 2024-10-31 00:32:18,334 - INFO - Fetching repositories for eKuG, page 2
# 2024-10-31 00:32:19,058 - INFO - Fetching repositories for Vikranth3140, page 1
# 2024-10-31 00:32:20,324 - INFO - Fetching repositories for aparna2071, page 1
# 2024-10-31 00:32:21,604 - INFO - Fetching repositories for mittrayash, page 1
# 2024-10-31 00:32:22,605 - INFO - Fetching repositories for darecoder, page 1
# 2024-10-31 00:32:23,834 - INFO - Fetching repositories for amanjeetsingh150, page 1
# 2024-10-31 00:32:25,414 - INFO - Fetching repositories for MeghnaS21, page 1
# 2024-10-31 00:32:27,355 - INFO - Fetching repositories for MeghnaS21, page 2
# 2024-10-31 00:32:28,149 - INFO - Fetching repositories for aggarwalpulkit596, page 1
# 2024-10-31 00:32:30,185 - INFO - Fetching repositories for aggarwalpulkit596, page 2
# 2024-10-31 00:32:31,096 - INFO - Fetching repositories for niks-nikhil-anand, page 1
# 2024-10-31 00:32:33,099 - INFO - Fetching repositories for Nistha-tech, page 1
# 2024-10-31 00:32:35,566 - INFO - Fetching repositories for Nistha-tech, page 2
# 2024-10-31 00:32:36,418 - INFO - Fetching repositories for m-sehrawat, page 1
# 2024-10-31 00:32:37,237 - INFO - Fetching repositories for nameisjayant, page 1
# 2024-10-31 00:32:38,781 - INFO - Fetching repositories for nameisjayant, page 2
# 2024-10-31 00:32:40,560 - INFO - Fetching repositories for kishanrajput23, page 1
# 2024-10-31 00:32:42,215 - INFO - Fetching repositories for kishanrajput23, page 2
# 2024-10-31 00:32:43,675 - INFO - Fetching repositories for rajneeshkumar146, page 1
# 2024-10-31 00:32:44,610 - INFO - Fetching repositories for IamJapneet, page 1
# 2024-10-31 00:32:45,556 - INFO - Fetching repositories for Hassan-Shoayb, page 1
# 2024-10-31 00:32:46,444 - INFO - Fetching repositories for Delta456, page 1
# 2024-10-31 00:32:47,874 - INFO - Fetching repositories for ashishrawat2911, page 1
# 2024-10-31 00:32:49,855 - INFO - Fetching repositories for ashishrawat2911, page 2
# 2024-10-31 00:32:52,345 - INFO - Fetching repositories for ashishrawat2911, page 3
# 2024-10-31 00:32:52,888 - INFO - Fetching repositories for nikhilroxtomar, page 1
# 2024-10-31 00:32:54,848 - INFO - Fetching repositories for nikhilroxtomar, page 2
# 2024-10-31 00:32:56,579 - INFO - Fetching repositories for nikhilroxtomar, page 3
# 2024-10-31 00:32:58,626 - INFO - Fetching repositories for amitsrivastava4all, page 1
# 2024-10-31 00:32:59,993 - INFO - Fetching repositories for amitsrivastava4all, page 2
# 2024-10-31 00:33:02,245 - INFO - Fetching repositories for mohak1283, page 1
# 2024-10-31 00:33:03,537 - INFO - Fetching repositories for Aashishkumar123, page 1
# 2024-10-31 00:33:04,838 - INFO - Fetching repositories for Pradeep-Pandey13, page 1
# 2024-10-31 00:33:05,683 - INFO - Fetching repositories for iamdeepak199, page 1
# 2024-10-31 00:33:06,701 - INFO - Fetching repositories for plibither8, page 1
# 2024-10-31 00:33:08,089 - INFO - Fetching repositories for softvar, page 1
# 2024-10-31 00:33:09,157 - INFO - Fetching repositories for saloniankita, page 1
# 2024-10-31 00:33:10,595 - INFO - Fetching repositories for iAyon, page 1
# 2024-10-31 00:33:11,139 - INFO - Fetching repositories for V4NSH4J, page 1
# 2024-10-31 00:33:11,745 - INFO - Fetching repositories for Samarth0606, page 1
# 2024-10-31 00:33:13,868 - INFO - Fetching repositories for dswh, page 1
# 2024-10-31 00:33:15,033 - INFO - Fetching repositories for JapneetSachdeva1, page 1
# 2024-10-31 00:33:15,901 - INFO - Fetching repositories for Deepaksharma-39, page 1
# 2024-10-31 00:33:16,936 - INFO - Fetching repositories for chandanverma07, page 1
# 2024-10-31 00:33:17,915 - INFO - Fetching repositories for vihaankapoor, page 1
# 2024-10-31 00:33:18,386 - INFO - Fetching repositories for EtishaGarg, page 1
# 2024-10-31 00:33:19,441 - INFO - Fetching repositories for viperadnan-git, page 1
# 2024-10-31 00:33:20,577 - INFO - Fetching repositories for sharmaadityaHQ, page 1
# 2024-10-31 00:33:21,816 - INFO - Fetching repositories for jatinkatyal13, page 1
# 2024-10-31 00:33:23,073 - INFO - Fetching repositories for jatinkatyal13, page 2
# 2024-10-31 00:33:24,299 - INFO - Fetching repositories for navdeep1676, page 1
# 2024-10-31 00:33:25,284 - INFO - Fetching repositories for Bhupesh-V, page 1
# 2024-10-31 00:33:26,473 - INFO - Fetching repositories for parikshit223933, page 1
# 2024-10-31 00:33:28,201 - INFO - Fetching repositories for vrijraj, page 1
# 2024-10-31 00:33:31,025 - INFO - Fetching repositories for vrijraj, page 2
# 2024-10-31 00:33:32,655 - INFO - Fetching repositories for ajayyadavexpo, page 1
# 2024-10-31 00:33:34,548 - INFO - Fetching repositories for iashris, page 1
# 2024-10-31 00:33:36,274 - INFO - Fetching repositories for iashris, page 2
# 2024-10-31 00:33:37,029 - INFO - Fetching repositories for H-a-r-s-h-i-t-a-k, page 1
# 2024-10-31 00:33:37,988 - INFO - Fetching repositories for mayank408, page 1
# 2024-10-31 00:33:39,975 - INFO - Fetching repositories for JyotinderSingh, page 1
# 2024-10-31 00:33:42,467 - INFO - Fetching repositories for ayush2390, page 1
# 2024-10-31 00:33:44,876 - INFO - Fetching repositories for ayush221b, page 1
# 2024-10-31 00:33:47,428 - INFO - Fetching repositories for TheHamkerCat, page 1
# 2024-10-31 00:33:48,577 - INFO - Fetching repositories for prateek-bka, page 1
# 2024-10-31 00:33:49,898 - INFO - Fetching repositories for mansimarkaur, page 1
# 2024-10-31 00:33:50,864 - INFO - Fetching repositories for keshavgbpecdelhi, page 1
# 2024-10-31 00:33:52,077 - INFO - Fetching repositories for keshavgbpecdelhi, page 2
# 2024-10-31 00:33:53,218 - INFO - Fetching repositories for kunaal438, page 1
# 2024-10-31 00:33:54,308 - INFO - Fetching repositories for jainaman224, page 1
# 2024-10-31 00:33:55,665 - INFO - Fetching repositories for jaidevd, page 1
# 2024-10-31 00:33:57,396 - INFO - Fetching repositories for jaidevd, page 2
# 2024-10-31 00:33:58,584 - INFO - Fetching repositories for devaar100, page 1
# 2024-10-31 00:34:00,507 - INFO - Fetching repositories for gptkrsh, page 1
# 2024-10-31 00:34:01,429 - INFO - Fetching repositories for Daksh777, page 1
# 2024-10-31 00:34:02,464 - INFO - Fetching repositories for Bhupender2, page 1
# 2024-10-31 00:34:03,759 - INFO - Fetching repositories for ConnectBhawna, page 1
# 2024-10-31 00:34:05,965 - INFO - Fetching repositories for ConnectBhawna, page 2
# 2024-10-31 00:34:07,875 - INFO - Fetching repositories for SandhyaKapoor, page 1
# 2024-10-31 00:34:09,075 - INFO - Fetching repositories for PriyankaJhaTheAnalyst, page 1
# 2024-10-31 00:34:09,988 - INFO - Fetching repositories for nikit19, page 1
# 2024-10-31 00:34:12,606 - INFO - Fetching repositories for midopooler, page 1
# 2024-10-31 00:34:14,465 - INFO - Fetching repositories for satishwithcode, page 1
# 2024-10-31 00:34:15,616 - INFO - Fetching repositories for goelabhishek694, page 1
# 2024-10-31 00:34:18,420 - INFO - Fetching repositories for devjs1000, page 1
# 2024-10-31 00:34:19,364 - INFO - Fetching repositories for prateek147, page 1
# 2024-10-31 00:34:20,315 - INFO - Fetching repositories for raj74434, page 1
# 2024-10-31 00:34:21,575 - INFO - Fetching repositories for VinayKumar1801, page 1
# 2024-10-31 00:34:22,474 - INFO - Fetching repositories for apnacollege, page 1
# 2024-10-31 00:34:23,093 - INFO - Fetching repositories for Ghanishtkhurana, page 1
# 2024-10-31 00:34:24,083 - INFO - Fetching repositories for thenamankumar, page 1
# 2024-10-31 00:34:25,755 - INFO - Fetching repositories for thenamankumar, page 2
# 2024-10-31 00:34:26,626 - INFO - Fetching repositories for Mokshit06, page 1
# 2024-10-31 00:34:29,088 - INFO - Fetching repositories for anupammaurya6767, page 1
# 2024-10-31 00:34:31,161 - INFO - Fetching repositories for anupammaurya6767, page 2
# 2024-10-31 00:34:32,147 - INFO - Fetching repositories for sara-02, page 1
# 2024-10-31 00:34:34,008 - INFO - Fetching repositories for sara-02, page 2
# 2024-10-31 00:34:36,000 - INFO - Fetching repositories for developer-shivam, page 1
# 2024-10-31 00:34:37,200 - INFO - Fetching repositories for mohak1712, page 1
# 2024-10-31 00:34:39,140 - INFO - Fetching repositories for vinaysomawat, page 1
# 2024-10-31 00:34:40,068 - INFO - Fetching repositories for bhavukjain1, page 1
# 2024-10-31 00:34:41,061 - INFO - Fetching repositories for shikharkumar13, page 1
# 2024-10-31 00:34:41,791 - INFO - Fetching repositories for AVIVASHISHTA29, page 1
# 2024-10-31 00:34:43,220 - INFO - Fetching repositories for AVIVASHISHTA29, page 2
# 2024-10-31 00:34:43,995 - INFO - Fetching repositories for shijithpk, page 1
# 2024-10-31 00:34:45,443 - INFO - Fetching repositories for itsmehacker, page 1
# 2024-10-31 00:34:46,135 - INFO - Fetching repositories for CodingWallah, page 1
# 2024-10-31 00:34:46,810 - INFO - Fetching repositories for NaziaSayyad, page 1
# 2024-10-31 00:34:48,509 - INFO - Fetching repositories for rohanraarora, page 1
# 2024-10-31 00:34:51,393 - INFO - Fetching repositories for rohanraarora, page 2
# 2024-10-31 00:34:52,294 - INFO - Fetching repositories for Rashmigautam16, page 1
# 2024-10-31 00:34:53,396 - INFO - Fetching repositories for harshithdwivedi, page 1
# 2024-10-31 00:34:54,514 - INFO - Fetching repositories for MukulCode, page 1
# 2024-10-31 00:34:56,306 - INFO - Fetching repositories for srbhr, page 1
# 2024-10-31 00:34:58,344 - INFO - Fetching repositories for srbhr, page 2
# 2024-10-31 00:34:59,726 - INFO - Fetching repositories for Ranjanji, page 1
# 2024-10-31 00:35:00,459 - INFO - Fetching repositories for raul-khan, page 1
# 2024-10-31 00:35:01,299 - INFO - Fetching repositories for rajat2502, page 1
# 2024-10-31 00:35:04,237 - INFO - Fetching repositories for rajat2502, page 2
# 2024-10-31 00:35:05,678 - INFO - Fetching repositories for adnan25042001, page 1
# 2024-10-31 00:35:07,619 - INFO - Fetching repositories for Kartik18g, page 1
# 2024-10-31 00:35:09,104 - INFO - Fetching repositories for Aarush-Goyal, page 1
# 2024-10-31 00:35:10,340 - INFO - Fetching repositories for masum-raja, page 1
# 2024-10-31 00:35:11,259 - INFO - Fetching repositories for chandan1506, page 1
# 2024-10-31 00:35:12,706 - INFO - Fetching repositories for sachuverma, page 1
# 2024-10-31 00:35:14,085 - INFO - Fetching repositories for Merciful123, page 1
# 2024-10-31 00:35:15,545 - INFO - Fetching repositories for himahuja, page 1
# 2024-10-31 00:35:16,990 - INFO - Fetching repositories for aflah02, page 1
# 2024-10-31 00:35:18,726 - INFO - Fetching repositories for aflah02, page 2
# 2024-10-31 00:35:20,879 - INFO - Fetching repositories for vikramram2001, page 1
# 2024-10-31 00:35:21,885 - INFO - Fetching repositories for shobhitsrivastava-ds, page 1
# 2024-10-31 00:35:25,413 - INFO - Fetching repositories for shobhitsrivastava-ds, page 2
# 2024-10-31 00:35:26,148 - INFO - Fetching repositories for kcubeterm, page 1
# 2024-10-31 00:35:26,795 - INFO - Fetching repositories for cyberfascinate, page 1
# 2024-10-31 00:35:27,597 - INFO - Fetching repositories for monumarquis, page 1
# 2024-10-31 00:35:28,479 - INFO - Fetching repositories for Udit-takkar, page 1
# 2024-10-31 00:35:30,845 - INFO - Fetching repositories for Udit-takkar, page 2
# 2024-10-31 00:35:32,315 - INFO - Fetching repositories for yashash-pugalia, page 1
# 2024-10-31 00:35:32,866 - INFO - Fetching repositories for vigzmv, page 1
# 2024-10-31 00:35:34,068 - INFO - Fetching repositories for vaibhavchellani, page 1
# 2024-10-31 00:35:35,395 - INFO - Fetching repositories for vaibhavchellani, page 2
# 2024-10-31 00:35:36,797 - INFO - Fetching repositories for ananyalohani, page 1
# 2024-10-31 00:35:38,133 - INFO - Fetching repositories for aditya12gusain, page 1
# 2024-10-31 00:35:39,423 - INFO - Fetching repositories for aditya12gusain, page 2
# 2024-10-31 00:35:40,035 - INFO - Fetching repositories for aasu14, page 1
# 2024-10-31 00:35:41,586 - INFO - Fetching repositories for ovaisazmi, page 1
# 2024-10-31 00:35:42,784 - INFO - Fetching repositories for imprakharshukla, page 1
# 2024-10-31 00:35:44,596 - INFO - Fetching repositories for souravjain540, page 1
# 2024-10-31 00:35:47,084 - INFO - Fetching repositories for souravjain540, page 2
# 2024-10-31 00:35:47,906 - INFO - Fetching repositories for ITZ-ZAID, page 1
# 2024-10-31 00:35:49,325 - INFO - Fetching repositories for suraj9716, page 1
# 2024-10-31 00:35:50,224 - INFO - Fetching repositories for AariF-ShazZ, page 1
# 2024-10-31 00:35:51,297 - INFO - Fetching repositories for shoaibrayeen, page 1
# 2024-10-31 00:35:52,135 - INFO - Fetching repositories for mrpkdeveloper, page 1
# 2024-10-31 00:35:53,419 - INFO - Fetching repositories for developerpaaji, page 1
# 2024-10-31 00:35:54,796 - INFO - Fetching repositories for Aniket965, page 1
# 2024-10-31 00:35:56,419 - INFO - Fetching repositories for Aniket965, page 2
# 2024-10-31 00:35:59,236 - INFO - Fetching repositories for CodeWithSwastik, page 1
# 2024-10-31 00:36:00,240 - INFO - Fetching repositories for ndpniraj, page 1
# 2024-10-31 00:36:01,525 - INFO - Fetching repositories for Gunnika, page 1
# 2024-10-31 00:36:03,033 - INFO - Fetching repositories for Aayushi-Mittal, page 1
# 2024-10-31 00:36:05,575 - INFO - Fetching repositories for creatorrr, page 1
# 2024-10-31 00:36:06,926 - INFO - Fetching repositories for creatorrr, page 2
# 2024-10-31 00:36:09,234 - INFO - Fetching repositories for creatorrr, page 3
# 2024-10-31 00:36:09,987 - INFO - Fetching repositories for Piryanshu88, page 1
# 2024-10-31 00:36:11,095 - INFO - Fetching repositories for 0786faizan, page 1
# 2024-10-31 00:36:11,908 - INFO - Fetching repositories for thevasudevgupta, page 1
# 2024-10-31 00:36:13,280 - INFO - Fetching repositories for Ashutosh00710, page 1
# 2024-10-31 00:36:14,419 - INFO - Fetching repositories for piyushhhxyz, page 1
# 2024-10-31 00:36:16,237 - INFO - Fetching repositories for lazycipher, page 1
# 2024-10-31 00:36:17,341 - INFO - Fetching repositories for rahulkr-dev, page 1
# 2024-10-31 00:36:18,815 - INFO - Fetching repositories for mohit2016, page 1
# 2024-10-31 00:36:20,955 - INFO - Fetching repositories for Sandeeprawat313, page 1
# 2024-10-31 00:36:21,824 - INFO - Fetching repositories for priyanshu2014204, page 1
# 2024-10-31 00:36:23,594 - INFO - Fetching repositories for vaidik, page 1
# 2024-10-31 00:36:24,765 - INFO - Fetching repositories for vaidik, page 2
# 2024-10-31 00:36:25,735 - INFO - Fetching repositories for tutorials-website, page 1
# 2024-10-31 00:36:26,743 - INFO - Fetching repositories for jatinkalwar, page 1
# 2024-10-31 00:36:27,584 - INFO - Fetching repositories for as1605, page 1
# 2024-10-31 00:36:28,934 - INFO - Fetching repositories for EkaanshArora, page 1
